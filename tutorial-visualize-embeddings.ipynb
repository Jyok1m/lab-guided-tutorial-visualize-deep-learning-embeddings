# %% [markdown]
# # Visualizing word embeddings : Deep Learning for NLP embeddings.
#
# This notebook will guide you through the implementation of Word2Vec, a popular model used in Natural Language Processing (NLP) to capture semantic meaning from text. We will apply this model to a dataset and visualize the learned word embeddings.

# %% [markdown]
# <center><img src="https://education-team-2020.s3.eu-west-1.amazonaws.com/ai-eng/w4-s3/deep_learning.png" width="1000"/></center>

# %% [markdown]
# ## Tutorial
#
# In this notebook, we will apply the Word2Vec model to a text dataset. The Word2Vec model learns to represent words in a continuous vector space, where semantically similar words are mapped to nearby points. We will walk through the following steps:
#
# 1. **Download the Training Data:** We'll start by downloading a large text corpus for training.
# 2. **Set up Word2Vec in TensorFlow:** We'll configure the Word2Vec model using TensorFlow, a popular machine learning library.
# 3. **Train the Model:** We'll train the Word2Vec model on the dataset to learn word embeddings.
# 4. **Visualize the Embeddings:** Finally, we'll visualize the learned word embeddings using dimensionality reduction techniques.

# %%
reset -fs

# %%
# I like to live dangerously ☠
import warnings
warnings.filterwarnings('ignore')

# %%
import collections
import math
import os
from pprint import pprint
import random
import urllib.request
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf 
from sklearn.manifold import TSNE

# %matplotlib inline

# %% [markdown]
# ### Step 1: Download the Dataset
#
# To train our Word2Vec model, we need a large text corpus. In this step, we will download the "text8" dataset, a popular dataset used for training word embeddings. This dataset contains 100 MB of English Wikipedia text from 2006, which is commonly used in NLP tasks.

# %%
url = 'http://mattmahoney.net/dc/'

def download(path, filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    
    if not os.path.exists(path+filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    
    statinfo = os.stat(path+filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    
    return filename

path = ""
filename = download(path, 'text8.zip', 31_344_016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# > **Note:** While the dataset is being downloaded, feel free to look ahead at the upcoming code cells to get a sense of what we'll be doing next.

# %%
# Read the data into a list of strings.
def read_data(path, filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(path+filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

vocabulary = read_data(path, filename)
print('Dataset size: {:,} words'.format(len(vocabulary)))
# Out:
# Dataset size: 17,005,207 words

# %%
# Take a peak at the head
vocabulary[:20]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english']

# %% [markdown]
# ### Observations on Preprocessing
#
# - **Case and Punctuation:** Notice that none of the words in our dataset are capitalized, and there is no punctuation. This is likely due to preprocessing steps taken before we acquired the dataset, which ensures uniformity in the text.
# - **Preprocessing Considerations:** Preprocessing is a crucial part of NLP tasks, and its specifics depend on the data and the intended use. For instance, while we're working with unigrams (single words), other tasks might benefit from encoding n-grams (combinations of words) to capture context better.

# %% [markdown]
# -----
# Step 2: Build the dictionary
# -----

# %% [markdown]
# Now that we have our text data, the next step is to build a dictionary. This dictionary will map each unique word in our dataset to a unique integer code.
#
# Additionally, we'll keep track of the frequency of each word, which will help us prioritize the most common words.

# %%
vocabulary_size = 50_000

def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)

# %% [markdown]
# ### Understanding the Key Variables
#
# - **`data`:** A list of integer codes representing the words in the original text. Each word is replaced by its corresponding code from the `dictionary`.
# - **`count`:** A list of tuples where each tuple contains a word and its frequency count in the dataset.
# - **`dictionary`:** A dictionary mapping each word to its unique integer code.
# - **`reverse_dictionary`:** A reverse mapping that converts integer codes back to their corresponding words.

# %%
del vocabulary # Reduce memory by getting rid of the "heavy" list of strings

# %%
data[:5] # An index of each word (as it appears in order) to its rank. Therefore we don't have reference the string
# Out:
# [5234, 3081, 12, 6, 195]

# %%
dictionary['the'] # word: rank
# Out:
# 1

# %%
reverse_dictionary[5234] # rank: word
# Out:
# 'anarchism'

# %%
print('Most common words:') 
print(*count[:5], sep="\n")
# Out:
# Most common words:
# ['UNK', 418391]
# ('the', 1061396)
# ('of', 593677)
# ('and', 416629)
# ('one', 411764)

# %%
print('Least common words:')
print(*count[-5:], sep="\n")
# Out:
# Least common words:
# ('codeword', 9)
# ('senussi', 9)
# ('unscr', 9)
# ('leonards', 9)
# ('hif', 9)

# %% [markdown]
# ### Step 3: Generate a Training Batch for the Skip-Gram Model
#
# In this step, we'll create a function to generate training batches for our skip-gram model. The skip-gram model is a variant of Word2Vec that predicts the context words given a target word. This function will help us prepare the data in the correct format for training the model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer[:] = data[:span]
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

batch, labels = generate_batch(batch_size=8, 
                               num_skips=2, 
                               skip_window=1)

# Example of self-supervised learning
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of

# %% [markdown]
# ----
# Step 4: Build and train a skip-gram model.
# -----
#
# The Skip-Gram model is a type of neural network model used in Natural Language Processing (NLP) to learn distributed representations of words, commonly known as word embeddings.
#
# Word embeddings are dense vector representations of words that capture semantic relationships between them, meaning that words with similar meanings are mapped to similar points in the vector space.
#
# ### How the Skip-Gram Model Works
# The goal of the Skip-Gram model is to predict the context words given a target word. Here's how it works:
#
# Input: The model takes a single word (the target word) from the text as input.
#
# Output: The model is trained to predict words that are likely to appear in the context of the target word within a specified window of words before and after the target word. This context window is typically referred to as the "skip window."
#
# For example, if the sentence is "The cat sat on the mat," and the target word is "sat," the model might be asked to predict the words "The," "cat," "on," and "the," which appear around "sat."

# %%
import tensorflow.compat.v1 as v1 # type: ignore

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_inputs = v1.placeholder(tf.int32, shape=[batch_size])
    train_labels = v1.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = v1.constant(valid_examples, dtype=tf.int32)

    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            v1.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            v1.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

        # Compute the average NCE loss for the batch.
        # tf.nce_loss automatically draws a new sample of the negative labels each
        # time we evaluate the loss.
        # Explanation of the meaning of NCE loss:
        #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
        loss = tf.reduce_mean(
          tf.nn.nce_loss(weights=nce_weights,
                         biases=nce_biases,
                         labels=train_labels,
                         inputs=embed,
                         num_sampled=num_sampled,
                         num_classes=vocabulary_size))

        # Construct the SGD optimizer using a learning rate of 1.0.
        optimizer = v1.train.GradientDescentOptimizer(1.0).minimize(loss)

        # Compute the cosine similarity between minibatch examples and all embeddings.
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(
          normalized_embeddings, valid_dataset)
        similarity = tf.matmul(
          valid_embeddings, normalized_embeddings, transpose_b=True)

        # Add variable initializer.
        init = v1.global_variables_initializer()

# %% [markdown]
# ----
# Step 5: Begin training.
# -----

# %%
num_steps = 100_001 #1 #2_001 #100_001

with v1.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2_000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 2_000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 4 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to '%s':" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
            print()
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  262.78644
# Nearest to 'that': feline, polka, active, como,
# Nearest to 'were': plasmid, doesn, rk, general,
# Nearest to 'after': crowned, autonegotiation, furthest, erasure,
# Nearest to 'years': pastimes, prostate, credo, kush,
# Nearest to 'one': selma, risorgimento, shamans, critically,
# Nearest to 'in': abusing, dismantle, apuleius, emanated,
# Nearest to 'between': mujahedin, dueling, miata, glucagon,
# Nearest to 'which': seditious, crewmembers, photosynthesis, signers,
# Nearest to 'new': washington, rectify, ccds, expressed,
# Nearest to 'd': suitability, log, suras, abnormally,
# Nearest to 'known': shannon, language, reunion, strangle,
# Nearest to 'had': bicarbonate, cards, ringworld, cocoa,
# Nearest to 'time': bundesland, cornwall, biog, fife,
# Nearest to 'but': wendell, pancho, rodr, lyne,
# Nearest to 'not': imprecise, mjt, export, chamorro,
# Nearest to 'five': brill, uri, plummeted, simone,
#
# Average loss at step  2000 :  113.74224
# Nearest to 'that': french, active, performance, de,
# Nearest to 'were': general, rebellion, wyatt, humanity,
# Nearest to 'after': signs, have, science, deals,
# Nearest to 'years': port, along, iron, four,
# Nearest to 'one': growing, products, nfc, carry,
# Nearest to 'in': of, dividing, awarded, and,
# Nearest to 'between': union, low, vs, soil,
# Nearest to 'which': particularly, trade, address, extraterrestrial,
# Nearest to 'new': washington, expressed, experience, times,
# Nearest to 'd': real, did, cia, partly,
# Nearest to 'known': language, peikoff, major, africans,
# Nearest to 'had': cards, act, chadic, exceed,
# Nearest to 'time': neither, summit, red, win,
# Nearest to 'but': halley, nationalized, receiving, much,
# Nearest to 'not': family, autistics, ascii, matt,
# Nearest to 'five': authority, g, say, peninsula,
#
# Average loss at step  4000 :  52.778877
# Nearest to 'that': french, active, performance, de,
# Nearest to 'were': rebellion, general, dagny, wyatt,
# Nearest to 'after': signs, crowned, architecture, aq,
# Nearest to 'years': port, four, fao, along,
# Nearest to 'one': two, agave, farmers, gland,
# Nearest to 'in': of, and, dividing, to,
# Nearest to 'between': ng, boards, scientist, union,
# Nearest to 'which': photosynthesis, particularly, tissue, walk,
# Nearest to 'new': washington, expressed, experience, times,
# Nearest to 'd': real, did, pin, cia,
# Nearest to 'known': language, peikoff, differ, agency,
# Nearest to 'had': cards, mixture, exceed, act,
# Nearest to 'time': red, bundesland, neither, summit,
# Nearest to 'but': calgary, halley, alkane, csm,
# Nearest to 'not': cool, family, autistics, matt,
# Nearest to 'five': nuclear, authority, beliefs, g,
#
# Average loss at step  6000 :  33.220825
# Nearest to 'that': attila, performance, french, to,
# Nearest to 'were': nothing, wyatt, rebellion, dagny,
# Nearest to 'after': crowned, furthest, signs, architecture,
# Nearest to 'years': port, four, globular, category,
# Nearest to 'one': two, zero, agave, canadians,
# Nearest to 'in': of, and, is, by,
# Nearest to 'between': ng, boards, burial, mysore,
# Nearest to 'which': photosynthesis, particularly, tissue, surrounding,
# Nearest to 'new': washington, expressed, experience, basins,
# Nearest to 'd': real, did, pin, cia,
# Nearest to 'known': language, peikoff, armenia, differ,
# Nearest to 'had': cards, cordite, mixture, immediately,
# Nearest to 'time': red, neither, inter, bundesland,
# Nearest to 'but': and, calgary, halley, trio,
# Nearest to 'not': cool, heuristic, UNK, family,
# Nearest to 'five': ngc, zero, penalties, authority,
#
# Average loss at step  8000 :  23.23304
# Nearest to 'that': attila, UNK, french, performance,
# Nearest to 'were': is, nothing, wyatt, dagny,
# Nearest to 'after': hmong, crowned, signs, furthest,
# Nearest to 'years': port, four, globular, projected,
# Nearest to 'one': UNK, two, agave, zero,
# Nearest to 'in': of, UNK, and, by,
# Nearest to 'between': ng, burial, union, mysore,
# Nearest to 'which': photosynthesis, particularly, UNK, tissue,
# Nearest to 'new': washington, expressed, experience, UNK,
# Nearest to 'd': real, pin, nazis, did,
# Nearest to 'known': language, peikoff, shannon, armenia,
# Nearest to 'had': cards, cordite, mixture, respectable,
# Nearest to 'time': gb, UNK, inter, red,
# Nearest to 'but': and, calgary, trio, halley,
# Nearest to 'not': UNK, derleth, cool, benzodiazepines,
# Nearest to 'five': zero, ngc, six, one,
#
# Average loss at step  10000 :  17.929747
# Nearest to 'that': and, attila, bodyline, notorious,
# Nearest to 'were': is, and, nothing, wyatt,
# Nearest to 'after': hmong, crowned, signs, furthest,
# Nearest to 'years': four, port, globular, projected,
# Nearest to 'one': two, nine, zero, bckgr,
# Nearest to 'in': and, of, by, nine,
# Nearest to 'between': and, levites, burial, mysore,
# Nearest to 'which': photosynthesis, particularly, archie, surrounding,
# Nearest to 'new': washington, expressed, experience, argentina,
# Nearest to 'd': pin, nazis, cia, real,
# Nearest to 'known': language, peikoff, shannon, armenia,
# Nearest to 'had': cards, cordite, polemical, mixture,
# Nearest to 'time': gb, capitalists, inter, summit,
# Nearest to 'but': and, calgary, trio, solid,
# Nearest to 'not': derleth, cool, benzodiazepines, that,
# Nearest to 'five': zero, six, three, nine,
#
# Average loss at step  12000 :  14.044025
# Nearest to 'that': attila, and, bodyline, hans,
# Nearest to 'were': is, and, gnat, nothing,
# Nearest to 'after': hmong, crowned, signs, canon,
# Nearest to 'years': four, port, globular, category,
# Nearest to 'one': two, nine, zero, bckgr,
# Nearest to 'in': and, by, of, from,
# Nearest to 'between': and, levites, gollancz, burial,
# Nearest to 'which': photosynthesis, also, and, particularly,
# Nearest to 'new': washington, expressed, experience, ccds,
# Nearest to 'd': nazis, pin, cia, real,
# Nearest to 'known': language, peikoff, shannon, differ,
# Nearest to 'had': cards, cordite, was, polemical,
# Nearest to 'time': gb, capitalists, inter, biog,
# Nearest to 'but': and, calgary, solid, trio,
# Nearest to 'not': to, derleth, that, it,
# Nearest to 'five': six, zero, one, nine,
#
# Average loss at step  14000 :  11.877083
# Nearest to 'that': and, attila, bodyline, dasyprocta,
# Nearest to 'were': is, are, and, gnat,
# Nearest to 'after': hmong, crowned, signs, canon,
# Nearest to 'years': four, port, globular, dasyprocta,
# Nearest to 'one': agouti, dasyprocta, two, circ,
# Nearest to 'in': and, of, by, agouti,
# Nearest to 'between': levites, and, dasyprocta, burial,
# Nearest to 'which': agouti, particularly, and, photosynthesis,
# Nearest to 'new': washington, agouti, experience, times,
# Nearest to 'd': pin, nazis, cia, dasyprocta,
# Nearest to 'known': language, peikoff, shannon, agouti,
# Nearest to 'had': cards, cordite, was, venn,
# Nearest to 'time': gb, dasyprocta, capitalists, inter,
# Nearest to 'but': and, calgary, trio, solid,
# Nearest to 'not': to, that, it, derleth,
# Nearest to 'five': agouti, six, zero, circ,
#
# Average loss at step  16000 :  9.989502
# Nearest to 'that': and, attila, bodyline, which,
# Nearest to 'were': is, are, and, was,
# Nearest to 'after': hmong, crowned, in, signs,
# Nearest to 'years': four, port, globular, projected,
# Nearest to 'one': agouti, dasyprocta, circ, two,
# Nearest to 'in': and, of, for, by,
# Nearest to 'between': and, dasyprocta, levites, agouti,
# Nearest to 'which': and, also, particularly, agouti,
# Nearest to 'new': washington, agouti, expressed, times,
# Nearest to 'd': and, nazis, pin, cia,
# Nearest to 'known': language, peikoff, shannon, agouti,
# Nearest to 'had': was, cordite, venn, cards,
# Nearest to 'time': gb, dasyprocta, capitalists, inter,
# Nearest to 'but': and, calgary, trio, dasyprocta,
# Nearest to 'not': it, that, to, derleth,
# Nearest to 'five': nine, six, zero, agouti,
#
# Average loss at step  18000 :  8.372062
# Nearest to 'that': and, attila, which, bodyline,
# Nearest to 'were': are, is, was, and,
# Nearest to 'after': hmong, crowned, in, signs,
# Nearest to 'years': four, port, globular, kush,
# Nearest to 'one': agouti, dasyprocta, circ, two,
# Nearest to 'in': of, and, from, by,
# Nearest to 'between': and, levites, with, dasyprocta,
# Nearest to 'which': and, also, that, agouti,
# Nearest to 'new': washington, agouti, times, experience,
# Nearest to 'd': and, b, cia, nazis,
# Nearest to 'known': language, shannon, peikoff, reunion,
# Nearest to 'had': was, cordite, venn, polemical,
# Nearest to 'time': gb, dasyprocta, capitalists, inter,
# Nearest to 'but': and, calgary, trio, solid,
# Nearest to 'not': it, to, that, derleth,
# Nearest to 'five': nine, six, zero, three,
#
# Average loss at step  20000 :  8.08542
# Nearest to 'that': and, which, attila, bodyline,
# Nearest to 'were': are, is, was, gnat,
# Nearest to 'after': hmong, crowned, in, canon,
# Nearest to 'years': four, port, dasyprocta, kush,
# Nearest to 'one': two, agouti, eight, seven,
# Nearest to 'in': and, of, for, from,
# Nearest to 'between': and, in, with, levites,
# Nearest to 'which': and, that, also, mercia,
# Nearest to 'new': washington, agouti, times, experience,
# Nearest to 'd': and, b, nazis, cia,
# Nearest to 'known': language, peikoff, shannon, agouti,
# Nearest to 'had': was, cordite, were, has,
# Nearest to 'time': gb, dasyprocta, inter, capitalists,
# Nearest to 'but': and, is, calgary, trio,
# Nearest to 'not': it, to, they, antwerp,
# Nearest to 'five': six, nine, zero, three,
#
# Average loss at step  22000 :  7.01844
# Nearest to 'that': which, and, attila, circ,
# Nearest to 'were': are, is, was, gnat,
# Nearest to 'after': hmong, in, crowned, furthest,
# Nearest to 'years': four, dasyprocta, port, two,
# Nearest to 'one': two, agouti, three, six,
# Nearest to 'in': and, of, for, on,
# Nearest to 'between': and, in, with, or,
# Nearest to 'which': that, abet, and, also,
# Nearest to 'new': washington, agouti, times, experience,
# Nearest to 'd': and, b, nazis, cia,
# Nearest to 'known': language, peikoff, shannon, differ,
# Nearest to 'had': was, cordite, were, have,
# Nearest to 'time': gb, dasyprocta, inter, fife,
# Nearest to 'but': and, is, trio, calgary,
# Nearest to 'not': it, to, they, antwerp,
# Nearest to 'five': six, nine, zero, eight,
#
# Average loss at step  24000 :  6.843007
# Nearest to 'that': which, attila, and, emerging,
# Nearest to 'were': are, was, is, gnat,
# Nearest to 'after': hmong, in, crowned, furthest,
# Nearest to 'years': four, relocated, stepmother, projected,
# Nearest to 'one': two, agouti, eight, seven,
# Nearest to 'in': and, of, agouti, by,
# Nearest to 'between': and, with, in, levites,
# Nearest to 'which': that, also, abet, this,
# Nearest to 'new': washington, agouti, experience, times,
# Nearest to 'd': and, b, nazis, cia,
# Nearest to 'known': language, peikoff, shannon, agouti,
# Nearest to 'had': was, have, has, were,
# Nearest to 'time': gb, dasyprocta, inter, fife,
# Nearest to 'but': and, trio, is, dasyprocta,
# Nearest to 'not': it, they, antwerp, to,
# Nearest to 'five': six, nine, zero, eight,
#
# Average loss at step  26000 :  6.7674785
# Nearest to 'that': which, attila, emerging, bodyline,
# Nearest to 'were': are, was, is, gnat,
# Nearest to 'after': hmong, in, crowned, furthest,
# Nearest to 'years': four, relocated, stepmother, projected,
# Nearest to 'one': two, six, agouti, eight,
# Nearest to 'in': and, agouti, nine, on,
# Nearest to 'between': and, with, in, or,
# Nearest to 'which': that, also, abet, this,
# Nearest to 'new': washington, agouti, experience, ccds,
# Nearest to 'd': b, and, nazis, cia,
# Nearest to 'known': peikoff, language, agouti, shannon,
# Nearest to 'had': was, has, have, were,
# Nearest to 'time': gb, inter, dasyprocta, combinations,
# Nearest to 'but': and, dasyprocta, trio, calgary,
# Nearest to 'not': it, they, to, antwerp,
# Nearest to 'five': six, four, nine, eight,
#
# Average loss at step  28000 :  6.407249
# Nearest to 'that': which, attila, this, emerging,
# Nearest to 'were': are, was, is, have,
# Nearest to 'after': hmong, in, crowned, bears,
# Nearest to 'years': four, relocated, projected, stepmother,
# Nearest to 'one': two, agouti, eight, dasyprocta,
# Nearest to 'in': and, on, of, at,
# Nearest to 'between': and, with, in, or,
# Nearest to 'which': that, also, and, abet,
# Nearest to 'new': washington, agouti, experience, technologically,
# Nearest to 'd': b, and, cia, nazis,
# Nearest to 'known': peikoff, language, shannon, abused,
# Nearest to 'had': was, has, have, were,
# Nearest to 'time': inter, gb, dasyprocta, fife,
# Nearest to 'but': and, or, although, dasyprocta,
# Nearest to 'not': it, they, to, antwerp,
# Nearest to 'five': six, four, eight, nine,
#
# Average loss at step  30000 :  5.8588505
# Nearest to 'that': which, attila, this, but,
# Nearest to 'were': are, was, is, have,
# Nearest to 'after': hmong, in, crowned, bears,
# Nearest to 'years': four, relocated, stepmother, projected,
# Nearest to 'one': two, agouti, eight, dasyprocta,
# Nearest to 'in': by, on, and, nine,
# Nearest to 'between': with, and, in, burial,
# Nearest to 'which': that, this, also, it,
# Nearest to 'new': washington, agouti, technologically, ccds,
# Nearest to 'd': b, and, nazis, cia,
# Nearest to 'known': peikoff, language, abused, agouti,
# Nearest to 'had': was, has, have, were,
# Nearest to 'time': inter, dasyprocta, gb, fife,
# Nearest to 'but': and, dasyprocta, circ, or,
# Nearest to 'not': it, they, to, inflate,
# Nearest to 'five': six, four, zero, eight,
#
# Average loss at step  32000 :  5.971342
# Nearest to 'that': which, this, attila, but,
# Nearest to 'were': are, was, is, have,
# Nearest to 'after': in, hmong, crowned, bears,
# Nearest to 'years': four, relocated, stepmother, credo,
# Nearest to 'one': two, three, seven, agouti,
# Nearest to 'in': and, nine, at, on,
# Nearest to 'between': and, with, in, or,
# Nearest to 'which': that, this, and, also,
# Nearest to 'new': agouti, washington, technologically, dasyprocta,
# Nearest to 'd': b, and, nazis, cia,
# Nearest to 'known': language, peikoff, abused, shannon,
# Nearest to 'had': was, have, has, were,
# Nearest to 'time': inter, dasyprocta, gb, fife,
# Nearest to 'but': and, or, although, dasyprocta,
# Nearest to 'not': it, they, to, antwerp,
# Nearest to 'five': six, four, eight, three,
#
# Average loss at step  34000 :  5.716872
# Nearest to 'that': which, this, but, attila,
# Nearest to 'were': are, was, is, have,
# Nearest to 'after': hmong, in, from, crowned,
# Nearest to 'years': four, relocated, stepmother, credo,
# Nearest to 'one': two, agouti, three, seven,
# Nearest to 'in': and, on, agouti, at,
# Nearest to 'between': and, in, with, burial,
# Nearest to 'which': that, this, also, and,
# Nearest to 'new': agouti, washington, technologically, dasyprocta,
# Nearest to 'd': b, and, nazis, cia,
# Nearest to 'known': vma, peikoff, abused, language,
# Nearest to 'had': was, have, has, were,
# Nearest to 'time': inter, dasyprocta, gb, combinations,
# Nearest to 'but': and, although, dasyprocta, circ,
# Nearest to 'not': it, they, to, also,
# Nearest to 'five': four, six, three, eight,
#
# Average loss at step  36000 :  5.796669
# Nearest to 'that': which, this, but, attila,
# Nearest to 'were': are, was, is, have,
# Nearest to 'after': in, hmong, from, at,
# Nearest to 'years': four, credo, stepmother, relocated,
# Nearest to 'one': two, three, seven, four,
# Nearest to 'in': at, and, on, agouti,
# Nearest to 'between': and, in, with, levites,
# Nearest to 'which': that, this, also, and,
# Nearest to 'new': agouti, washington, technologically, dasyprocta,
# Nearest to 'd': b, and, nazis, cia,
# Nearest to 'known': peikoff, abused, vma, language,
# Nearest to 'had': has, was, have, were,
# Nearest to 'time': dasyprocta, inter, aveiro, gb,
# Nearest to 'but': and, dasyprocta, circ, although,
# Nearest to 'not': it, they, to, also,
# Nearest to 'five': four, six, seven, three,
#
# Average loss at step  38000 :  5.509496
# Nearest to 'that': which, this, but, attila,
# Nearest to 'were': are, was, have, is,
# Nearest to 'after': in, hmong, from, bears,
# Nearest to 'years': four, credo, relocated, stepmother,
# Nearest to 'one': two, four, three, seven,
# Nearest to 'in': on, and, at, agouti,
# Nearest to 'between': with, and, in, from,
# Nearest to 'which': that, this, also, abet,
# Nearest to 'new': agouti, washington, technologically, dasyprocta,
# Nearest to 'd': b, and, nazis, cia,
# Nearest to 'known': abused, peikoff, language, vma,
# Nearest to 'had': has, was, have, were,
# Nearest to 'time': inter, dasyprocta, gb, aveiro,
# Nearest to 'but': and, dasyprocta, circ, agouti,
# Nearest to 'not': it, they, also, often,
# Nearest to 'five': four, six, three, eight,
#
# Average loss at step  40000 :  5.259576
# Nearest to 'that': which, this, but, attila,
# Nearest to 'were': are, was, have, is,
# Nearest to 'after': in, hmong, from, bears,
# Nearest to 'years': four, credo, relocated, stepmother,
# Nearest to 'one': two, eight, four, zero,
# Nearest to 'in': and, on, at, zero,
# Nearest to 'between': with, and, in, burial,
# Nearest to 'which': that, this, and, also,
# Nearest to 'new': agouti, washington, technologically, kriol,
# Nearest to 'd': b, and, nazis, doped,
# Nearest to 'known': abused, peikoff, vma, language,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': inter, dasyprocta, aveiro, gb,
# Nearest to 'but': and, that, although, dasyprocta,
# Nearest to 'not': it, they, to, also,
# Nearest to 'five': four, six, three, zero,
#
# Average loss at step  42000 :  5.387681
# Nearest to 'that': which, this, but, attila,
# Nearest to 'were': are, was, have, is,
# Nearest to 'after': in, hmong, from, agouti,
# Nearest to 'years': four, credo, relocated, stepmother,
# Nearest to 'one': two, four, six, seven,
# Nearest to 'in': on, at, and, agouti,
# Nearest to 'between': and, with, in, burial,
# Nearest to 'which': that, this, also, and,
# Nearest to 'new': agouti, washington, dasyprocta, kriol,
# Nearest to 'd': b, UNK, and, nazis,
# Nearest to 'known': abused, peikoff, vma, barbiturates,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': dasyprocta, inter, aveiro, gb,
# Nearest to 'but': and, although, dasyprocta, circ,
# Nearest to 'not': it, they, to, often,
# Nearest to 'five': four, six, seven, three,
#
# Average loss at step  44000 :  5.2735853
# Nearest to 'that': which, but, this, emerging,
# Nearest to 'were': are, was, have, had,
# Nearest to 'after': in, hmong, from, before,
# Nearest to 'years': four, relocated, credo, stepmother,
# Nearest to 'one': four, two, six, seven,
# Nearest to 'in': and, at, on, agouti,
# Nearest to 'between': with, in, and, burial,
# Nearest to 'which': that, this, also, abet,
# Nearest to 'new': agouti, washington, technologically, experience,
# Nearest to 'd': b, nazis, UNK, proclus,
# Nearest to 'known': abused, peikoff, vma, used,
# Nearest to 'had': have, has, was, were,
# Nearest to 'time': inter, aveiro, dasyprocta, combinations,
# Nearest to 'but': and, although, however, or,
# Nearest to 'not': it, they, to, also,
# Nearest to 'five': six, four, three, seven,
#
# Average loss at step  46000 :  5.242318
# Nearest to 'that': which, this, but, emerging,
# Nearest to 'were': are, was, have, is,
# Nearest to 'after': in, from, hmong, before,
# Nearest to 'years': four, relocated, credo, stepmother,
# Nearest to 'one': two, four, six, agouti,
# Nearest to 'in': at, on, agouti, and,
# Nearest to 'between': with, and, in, from,
# Nearest to 'which': that, this, also, and,
# Nearest to 'new': agouti, washington, dasyprocta, kriol,
# Nearest to 'd': b, and, nazis, UNK,
# Nearest to 'known': used, abused, peikoff, vma,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': dasyprocta, inter, aveiro, gb,
# Nearest to 'but': and, however, dasyprocta, circ,
# Nearest to 'not': it, they, also, to,
# Nearest to 'five': four, six, three, seven,
#
# Average loss at step  48000 :  5.2247605
# Nearest to 'that': which, this, but, emerging,
# Nearest to 'were': are, was, have, had,
# Nearest to 'after': in, from, before, hmong,
# Nearest to 'years': relocated, credo, stepmother, four,
# Nearest to 'one': two, four, six, three,
# Nearest to 'in': on, at, and, during,
# Nearest to 'between': with, and, in, from,
# Nearest to 'which': that, this, and, also,
# Nearest to 'new': agouti, washington, dasyprocta, kriol,
# Nearest to 'd': b, nazis, doped, UNK,
# Nearest to 'known': used, abused, peikoff, vma,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': kapoor, dasyprocta, inter, aveiro,
# Nearest to 'but': and, however, circ, dasyprocta,
# Nearest to 'not': it, they, also, to,
# Nearest to 'five': four, six, three, seven,
#
# Average loss at step  50000 :  5.0004134
# Nearest to 'that': which, this, but, emerging,
# Nearest to 'were': are, was, have, had,
# Nearest to 'after': in, from, before, hmong,
# Nearest to 'years': relocated, credo, stepmother, four,
# Nearest to 'one': two, four, three, six,
# Nearest to 'in': at, on, during, dasyprocta,
# Nearest to 'between': and, with, in, from,
# Nearest to 'which': that, this, and, also,
# Nearest to 'new': agouti, washington, dasyprocta, kriol,
# Nearest to 'd': b, and, nazis, doped,
# Nearest to 'known': used, abused, peikoff, vma,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': kapoor, aveiro, inter, dasyprocta,
# Nearest to 'but': and, however, although, or,
# Nearest to 'not': they, it, to, often,
# Nearest to 'five': four, six, three, seven,
#
# Average loss at step  52000 :  5.0503874
# Nearest to 'that': which, this, but, ursus,
# Nearest to 'were': are, was, have, had,
# Nearest to 'after': before, from, hmong, during,
# Nearest to 'years': relocated, credo, stepmother, ellen,
# Nearest to 'one': two, four, six, eight,
# Nearest to 'in': at, on, and, dasyprocta,
# Nearest to 'between': with, and, in, from,
# Nearest to 'which': that, this, also, and,
# Nearest to 'new': agouti, dasyprocta, washington, kriol,
# Nearest to 'd': b, and, nazis, doped,
# Nearest to 'known': used, abused, peikoff, vma,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': kapoor, dasyprocta, aveiro, inter,
# Nearest to 'but': and, ursus, however, circ,
# Nearest to 'not': ursus, it, they, to,
# Nearest to 'five': four, six, three, seven,
#
# Average loss at step  54000 :  5.177924
# Nearest to 'that': which, but, this, ursus,
# Nearest to 'were': are, was, have, had,
# Nearest to 'after': before, from, wct, in,
# Nearest to 'years': relocated, credo, stepmother, ellen,
# Nearest to 'one': two, eight, six, four,
# Nearest to 'in': at, on, nine, and,
# Nearest to 'between': with, and, in, levites,
# Nearest to 'which': that, this, also, abet,
# Nearest to 'new': agouti, dasyprocta, kriol, micro,
# Nearest to 'd': b, and, nazis, six,
# Nearest to 'known': used, abused, peikoff, tuck,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': kapoor, dasyprocta, inter, aveiro,
# Nearest to 'but': and, ursus, however, although,
# Nearest to 'not': ursus, they, it, often,
# Nearest to 'five': four, six, three, eight,
#
# Average loss at step  56000 :  5.057682
# Nearest to 'that': which, but, this, ursus,
# Nearest to 'were': are, was, have, had,
# Nearest to 'after': before, during, from, wct,
# Nearest to 'years': relocated, credo, stepmother, ellen,
# Nearest to 'one': two, six, three, four,
# Nearest to 'in': and, on, at, during,
# Nearest to 'between': with, in, and, levites,
# Nearest to 'which': that, this, also, abet,
# Nearest to 'new': microbats, agouti, washington, micro,
# Nearest to 'd': b, and, nazis, doped,
# Nearest to 'known': used, abused, peikoff, tuck,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': inter, kapoor, combinations, aveiro,
# Nearest to 'but': and, ursus, however, although,
# Nearest to 'not': ursus, they, it, also,
# Nearest to 'five': four, six, three, eight,
#
# Average loss at step  58000 :  5.066138
# Nearest to 'that': which, but, this, emerging,
# Nearest to 'were': are, was, have, had,
# Nearest to 'after': before, in, during, from,
# Nearest to 'years': credo, relocated, stepmother, ellen,
# Nearest to 'one': two, six, four, three,
# Nearest to 'in': at, and, on, during,
# Nearest to 'between': with, in, and, burial,
# Nearest to 'which': that, this, also, abet,
# Nearest to 'new': microbats, agouti, micro, washington,
# Nearest to 'd': b, and, nazis, doped,
# Nearest to 'known': used, abused, peikoff, tuck,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': inter, combinations, kapoor, aveiro,
# Nearest to 'but': and, however, although, ursus,
# Nearest to 'not': ursus, they, it, to,
# Nearest to 'five': four, six, three, eight,
#
# Average loss at step  60000 :  4.9718375
# Nearest to 'that': which, but, this, however,
# Nearest to 'were': are, was, have, had,
# Nearest to 'after': before, during, from, wct,
# Nearest to 'years': relocated, credo, stepmother, ellen,
# Nearest to 'one': two, six, four, three,
# Nearest to 'in': on, at, and, ursus,
# Nearest to 'between': with, and, in, from,
# Nearest to 'which': that, this, also, abet,
# Nearest to 'new': microbats, agouti, micro, washington,
# Nearest to 'd': b, nazis, atrophy, doped,
# Nearest to 'known': used, abused, peikoff, tuck,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': kapoor, inter, aveiro, combinations,
# Nearest to 'but': and, however, ursus, circ,
# Nearest to 'not': ursus, they, it, often,
# Nearest to 'five': four, six, three, eight,
#
# Average loss at step  62000 :  5.011354
# Nearest to 'that': which, this, but, however,
# Nearest to 'were': are, was, have, had,
# Nearest to 'after': before, during, from, when,
# Nearest to 'years': relocated, credo, stepmother, ellen,
# Nearest to 'one': two, four, six, three,
# Nearest to 'in': and, at, on, ursus,
# Nearest to 'between': with, in, burial, and,
# Nearest to 'which': that, this, also, abet,
# Nearest to 'new': microbats, agouti, micro, washington,
# Nearest to 'd': b, nazis, atrophy, catherine,
# Nearest to 'known': used, abused, well, tuck,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': kapoor, aveiro, inter, dasyprocta,
# Nearest to 'but': and, however, ursus, although,
# Nearest to 'not': ursus, it, they, often,
# Nearest to 'five': four, six, three, eight,
#
# Average loss at step  64000 :  4.8361425
# Nearest to 'that': which, but, this, however,
# Nearest to 'were': are, was, have, had,
# Nearest to 'after': before, during, wct, from,
# Nearest to 'years': relocated, credo, stepmother, four,
# Nearest to 'one': two, six, four, seven,
# Nearest to 'in': and, agouti, dasyprocta, at,
# Nearest to 'between': with, in, from, burial,
# Nearest to 'which': that, this, also, it,
# Nearest to 'new': microbats, agouti, micro, dasyprocta,
# Nearest to 'd': b, atrophy, nazis, catherine,
# Nearest to 'known': used, abused, well, vma,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': kapoor, aveiro, dasyprocta, combinations,
# Nearest to 'but': however, and, although, ursus,
# Nearest to 'not': ursus, they, it, also,
# Nearest to 'five': four, six, three, seven,
#
# Average loss at step  66000 :  4.627501
# Nearest to 'that': which, this, but, however,
# Nearest to 'were': are, was, have, had,
# Nearest to 'after': before, during, when, from,
# Nearest to 'years': relocated, credo, stepmother, ellen,
# Nearest to 'one': two, six, seven, four,
# Nearest to 'in': on, at, during, agouti,
# Nearest to 'between': with, from, in, burial,
# Nearest to 'which': that, this, also, abet,
# Nearest to 'new': microbats, agouti, micro, washington,
# Nearest to 'd': b, nazis, atrophy, catherine,
# Nearest to 'known': used, abused, dacko, well,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': kapoor, aveiro, dasyprocta, inter,
# Nearest to 'but': however, and, although, ursus,
# Nearest to 'not': they, ursus, it, often,
# Nearest to 'five': four, six, three, eight,
#
# Average loss at step  68000 :  4.973512
# Nearest to 'that': which, this, but, however,
# Nearest to 'were': are, have, was, had,
# Nearest to 'after': before, during, when, wct,
# Nearest to 'years': relocated, credo, stepmother, ellen,
# Nearest to 'one': two, six, seven, four,
# Nearest to 'in': at, and, agouti, dasyprocta,
# Nearest to 'between': with, burial, levites, from,
# Nearest to 'which': that, this, also, it,
# Nearest to 'new': microbats, agouti, micro, washington,
# Nearest to 'd': b, nazis, atrophy, catherine,
# Nearest to 'known': used, abused, well, dacko,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': kapoor, aveiro, combinations, dasyprocta,
# Nearest to 'but': and, however, although, ursus,
# Nearest to 'not': ursus, they, it, often,
# Nearest to 'five': four, six, three, eight,
#
# Average loss at step  70000 :  4.9019017
# Nearest to 'that': which, this, but, however,
# Nearest to 'were': are, have, was, had,
# Nearest to 'after': before, during, when, from,
# Nearest to 'years': relocated, credo, stepmother, ellen,
# Nearest to 'one': two, six, four, five,
# Nearest to 'in': at, dasyprocta, and, ursus,
# Nearest to 'between': with, levites, burial, tore,
# Nearest to 'which': that, this, also, it,
# Nearest to 'new': microbats, agouti, micro, washington,
# Nearest to 'd': b, atrophy, nazis, UNK,
# Nearest to 'known': used, abused, well, dacko,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': kapoor, combinations, aveiro, dasyprocta,
# Nearest to 'but': and, however, although, ursus,
# Nearest to 'not': they, ursus, it, often,
# Nearest to 'five': four, six, three, eight,
#
# Average loss at step  72000 :  4.746909
# Nearest to 'that': which, this, however, but,
# Nearest to 'were': are, have, was, had,
# Nearest to 'after': before, during, when, from,
# Nearest to 'years': relocated, credo, stepmother, ellen,
# Nearest to 'one': two, six, four, seven,
# Nearest to 'in': at, on, agouti, dasyprocta,
# Nearest to 'between': with, from, burial, levites,
# Nearest to 'which': that, this, also, it,
# Nearest to 'new': microbats, micro, agouti, washington,
# Nearest to 'd': b, atrophy, nazis, catherine,
# Nearest to 'known': used, abused, well, dacko,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': kapoor, aveiro, dasyprocta, combinations,
# Nearest to 'but': however, and, although, ursus,
# Nearest to 'not': ursus, they, it, often,
# Nearest to 'five': four, six, three, eight,
#
# Average loss at step  74000 :  4.8108287
# Nearest to 'that': which, but, this, however,
# Nearest to 'were': are, have, was, had,
# Nearest to 'after': before, during, from, when,
# Nearest to 'years': relocated, credo, stepmother, ellen,
# Nearest to 'one': six, two, four, seven,
# Nearest to 'in': at, on, agouti, dasyprocta,
# Nearest to 'between': with, from, levites, tore,
# Nearest to 'which': that, this, also, it,
# Nearest to 'new': microbats, micro, agouti, washington,
# Nearest to 'd': b, atrophy, nazis, seven,
# Nearest to 'known': used, abused, well, dacko,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': kapoor, combinations, aveiro, dasyprocta,
# Nearest to 'but': however, and, ursus, although,
# Nearest to 'not': they, ursus, it, often,
# Nearest to 'five': four, six, three, eight,
#
# Average loss at step  76000 :  4.7276297
# Nearest to 'that': which, however, but, this,
# Nearest to 'were': are, have, was, had,
# Nearest to 'after': before, during, when, from,
# Nearest to 'years': relocated, credo, stepmother, ellen,
# Nearest to 'one': two, six, four, seven,
# Nearest to 'in': at, during, and, agouti,
# Nearest to 'between': with, from, in, columbanus,
# Nearest to 'which': that, this, also, it,
# Nearest to 'new': microbats, agouti, micro, washington,
# Nearest to 'd': b, atrophy, nazis, catherine,
# Nearest to 'known': used, abused, well, differentiable,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': kapoor, combinations, aveiro, dasyprocta,
# Nearest to 'but': however, and, ursus, although,
# Nearest to 'not': ursus, they, often, to,
# Nearest to 'five': four, six, three, eight,
#
# Average loss at step  78000 :  4.7905936
# Nearest to 'that': which, however, but, this,
# Nearest to 'were': are, was, have, had,
# Nearest to 'after': before, during, when, from,
# Nearest to 'years': relocated, credo, stepmother, ellen,
# Nearest to 'one': four, six, seven, two,
# Nearest to 'in': at, agouti, dasyprocta, and,
# Nearest to 'between': with, from, columbanus, in,
# Nearest to 'which': that, this, also, it,
# Nearest to 'new': microbats, agouti, micro, washington,
# Nearest to 'd': b, atrophy, nazis, catherine,
# Nearest to 'known': used, abused, well, differentiable,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': combinations, kapoor, aveiro, dasyprocta,
# Nearest to 'but': however, and, ursus, although,
# Nearest to 'not': ursus, they, often, still,
# Nearest to 'five': four, six, eight, three,
#
# Average loss at step  80000 :  4.793761
# Nearest to 'that': which, this, however, but,
# Nearest to 'were': are, have, was, had,
# Nearest to 'after': before, during, when, from,
# Nearest to 'years': relocated, stepmother, credo, two,
# Nearest to 'one': six, two, seven, four,
# Nearest to 'in': at, agouti, during, dasyprocta,
# Nearest to 'between': with, from, in, textures,
# Nearest to 'which': that, this, also, it,
# Nearest to 'new': microbats, agouti, washington, micro,
# Nearest to 'd': b, atrophy, nazis, catherine,
# Nearest to 'known': used, abused, differentiable, well,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': kapoor, aveiro, combinations, dasyprocta,
# Nearest to 'but': however, and, although, ursus,
# Nearest to 'not': they, ursus, often, it,
# Nearest to 'five': four, six, seven, eight,
#
# Average loss at step  82000 :  4.7716894
# Nearest to 'that': which, however, but, this,
# Nearest to 'were': are, have, was, had,
# Nearest to 'after': before, during, when, from,
# Nearest to 'years': relocated, credo, stepmother, ellen,
# Nearest to 'one': two, six, seven, four,
# Nearest to 'in': at, agouti, dasyprocta, during,
# Nearest to 'between': with, from, textures, columbanus,
# Nearest to 'which': that, this, also, it,
# Nearest to 'new': microbats, agouti, washington, micro,
# Nearest to 'd': b, atrophy, catherine, nazis,
# Nearest to 'known': used, abused, well, differentiable,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': combinations, kapoor, dasyprocta, aveiro,
# Nearest to 'but': however, and, although, ursus,
# Nearest to 'not': they, ursus, often, it,
# Nearest to 'five': four, six, seven, eight,
#
# Average loss at step  84000 :  4.7651143
# Nearest to 'that': which, however, but, this,
# Nearest to 'were': are, was, have, had,
# Nearest to 'after': before, during, when, from,
# Nearest to 'years': relocated, credo, stepmother, ellen,
# Nearest to 'one': two, six, four, seven,
# Nearest to 'in': during, at, on, agouti,
# Nearest to 'between': with, from, textures, in,
# Nearest to 'which': that, this, also, it,
# Nearest to 'new': microbats, agouti, washington, micro,
# Nearest to 'd': b, atrophy, nazis, catherine,
# Nearest to 'known': used, abused, well, differentiable,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': combinations, kapoor, aveiro, dasyprocta,
# Nearest to 'but': however, and, although, ursus,
# Nearest to 'not': it, they, ursus, often,
# Nearest to 'five': four, six, seven, eight,
#
# Average loss at step  86000 :  4.773271
# Nearest to 'that': which, however, but, this,
# Nearest to 'were': are, have, was, had,
# Nearest to 'after': before, during, when, in,
# Nearest to 'years': relocated, credo, stepmother, ellen,
# Nearest to 'one': two, six, four, seven,
# Nearest to 'in': at, during, on, agouti,
# Nearest to 'between': with, from, in, textures,
# Nearest to 'which': that, this, also, it,
# Nearest to 'new': microbats, agouti, washington, micro,
# Nearest to 'd': b, atrophy, nazis, catherine,
# Nearest to 'known': used, well, abused, differentiable,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': combinations, kapoor, aveiro, dasyprocta,
# Nearest to 'but': however, and, although, ursus,
# Nearest to 'not': ursus, often, they, it,
# Nearest to 'five': four, six, seven, eight,
#
# Average loss at step  88000 :  4.7408924
# Nearest to 'that': which, however, but, this,
# Nearest to 'were': are, have, was, had,
# Nearest to 'after': before, during, when, in,
# Nearest to 'years': relocated, credo, stepmother, days,
# Nearest to 'one': two, four, six, three,
# Nearest to 'in': at, during, on, dasyprocta,
# Nearest to 'between': with, from, in, textures,
# Nearest to 'which': that, this, also, it,
# Nearest to 'new': microbats, washington, agouti, micro,
# Nearest to 'd': b, atrophy, catherine, nazis,
# Nearest to 'known': used, well, abused, differentiable,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': combinations, kapoor, aveiro, dasyprocta,
# Nearest to 'but': however, and, although, ursus,
# Nearest to 'not': often, they, ursus, it,
# Nearest to 'five': four, six, seven, eight,
#
# Average loss at step  90000 :  4.7267265
# Nearest to 'that': which, however, but, this,
# Nearest to 'were': are, have, was, had,
# Nearest to 'after': before, during, when, wct,
# Nearest to 'years': relocated, credo, stepmother, days,
# Nearest to 'one': two, four, three, seven,
# Nearest to 'in': during, at, dasyprocta, agouti,
# Nearest to 'between': with, from, in, textures,
# Nearest to 'which': that, this, also, it,
# Nearest to 'new': microbats, agouti, washington, dasyprocta,
# Nearest to 'd': b, atrophy, catherine, nazis,
# Nearest to 'known': used, well, abused, differentiable,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': combinations, kapoor, aveiro, gypsum,
# Nearest to 'but': however, and, although, ursus,
# Nearest to 'not': they, often, ursus, it,
# Nearest to 'five': four, seven, eight, six,
#
# Average loss at step  92000 :  4.65343
# Nearest to 'that': which, this, however, but,
# Nearest to 'were': are, have, was, had,
# Nearest to 'after': before, during, when, until,
# Nearest to 'years': relocated, credo, days, stepmother,
# Nearest to 'one': seven, two, four, five,
# Nearest to 'in': during, at, dasyprocta, agouti,
# Nearest to 'between': with, from, in, textures,
# Nearest to 'which': that, this, also, it,
# Nearest to 'new': microbats, agouti, washington, dasyprocta,
# Nearest to 'd': b, atrophy, catherine, four,
# Nearest to 'known': used, well, abused, differentiable,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': combinations, kapoor, dasyprocta, aveiro,
# Nearest to 'but': however, and, ursus, although,
# Nearest to 'not': they, ursus, often, it,
# Nearest to 'five': four, seven, eight, six,
#
# Average loss at step  94000 :  4.7202444
# Nearest to 'that': which, however, but, this,
# Nearest to 'were': are, have, had, was,
# Nearest to 'after': before, during, when, until,
# Nearest to 'years': relocated, days, credo, stepmother,
# Nearest to 'one': seven, two, four, six,
# Nearest to 'in': during, at, dasyprocta, and,
# Nearest to 'between': with, from, within, around,
# Nearest to 'which': that, this, also, abet,
# Nearest to 'new': microbats, agouti, washington, one,
# Nearest to 'd': b, atrophy, catherine, four,
# Nearest to 'known': used, well, abused, differentiable,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': combinations, kapoor, dasyprocta, aveiro,
# Nearest to 'but': however, and, although, ursus,
# Nearest to 'not': they, ursus, often, it,
# Nearest to 'five': four, seven, eight, six,
#
# Average loss at step  96000 :  4.6753154
# Nearest to 'that': which, however, this, but,
# Nearest to 'were': are, have, was, had,
# Nearest to 'after': before, during, when, wct,
# Nearest to 'years': relocated, days, credo, four,
# Nearest to 'one': six, two, seven, four,
# Nearest to 'in': at, dasyprocta, during, ursus,
# Nearest to 'between': with, chianti, from, around,
# Nearest to 'which': that, this, also, abet,
# Nearest to 'new': microbats, washington, agouti, micro,
# Nearest to 'd': b, atrophy, catherine, nazis,
# Nearest to 'known': used, well, abused, differentiable,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': combinations, kapoor, dasyprocta, aveiro,
# Nearest to 'but': however, and, although, ursus,
# Nearest to 'not': they, ursus, often, it,
# Nearest to 'five': four, seven, six, eight,
#
# Average loss at step  98000 :  4.5900145
# Nearest to 'that': which, however, this, but,
# Nearest to 'were': are, have, had, was,
# Nearest to 'after': before, during, when, until,
# Nearest to 'years': days, relocated, credo, four,
# Nearest to 'one': seven, six, two, eight,
# Nearest to 'in': at, during, ursus, on,
# Nearest to 'between': with, chianti, from, around,
# Nearest to 'which': that, this, also, abet,
# Nearest to 'new': microbats, washington, agouti, micro,
# Nearest to 'd': b, atrophy, catherine, nazis,
# Nearest to 'known': used, abused, well, such,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': combinations, kapoor, dasyprocta, aveiro,
# Nearest to 'but': however, and, although, while,
# Nearest to 'not': ursus, they, often, still,
# Nearest to 'five': four, six, seven, eight,
#
# Average loss at step  100000 :  4.6989675
# Nearest to 'that': which, however, this, but,
# Nearest to 'were': are, have, had, was,
# Nearest to 'after': before, during, when, until,
# Nearest to 'years': days, relocated, credo, four,
# Nearest to 'one': two, six, seven, four,
# Nearest to 'in': during, at, dasyprocta, on,
# Nearest to 'between': with, from, chianti, in,
# Nearest to 'which': that, this, also, abet,
# Nearest to 'new': microbats, washington, agouti, modern,
# Nearest to 'd': b, catherine, six, atrophy,
# Nearest to 'known': used, abused, well, such,
# Nearest to 'had': has, have, was, were,
# Nearest to 'time': combinations, kapoor, dasyprocta, aveiro,
# Nearest to 'but': however, and, although, ursus,
# Nearest to 'not': they, ursus, often, still,
# Nearest to 'five': four, seven, six, eight,

# %% [markdown]
# -----
# Step 6: Visualize the embeddings with t-SNE.
# ----

# %% [markdown]
# In this step, we use the t-SNE algorithm to reduce the dimensionality of the learned word embeddings for visualization.
#
# The top 500 words (based on frequency) are plotted in a 2D space, allowing us to visually inspect the relationships and groupings among words.
#
# This visualization is a powerful tool to understand how well the model has learned semantic relationships.

# %%
tsne = TSNE(perplexity=30, 
            n_components=2, 
            init='pca', 
            n_iter=5_000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]

n_words_to_visualize = 40

for i, label in enumerate(labels[:n_words_to_visualize]):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
# Out:
# /Users/joachimjasmin/.pyenv/versions/3.12.10/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %% [markdown]
# ------
#
# # Let's render and plot more samples.

# %%
# Fonction pour afficher les embeddings réduits (en 2D) avec les étiquettes de mots
def plot_with_labels(low_dim_embs, labels, filename='../images/tsne.png'):
    # Vérifie qu'on n'essaie pas d'afficher plus d'étiquettes qu'on a de vecteurs
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    
    # Crée une grande figure (18x18 pouces) pour bien voir les mots
    plt.figure(figsize=(18, 18))
    
    # Pour chaque mot (label) et son vecteur (x, y)
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        
        # Place un point sur le graphique
        plt.scatter(x, y)
        
        # Ajoute le mot à côté du point
        plt.annotate(
            label,                 # Le mot à afficher
            xy=(x, y),             # Position du point
            xytext=(5, 2),         # Décalage du texte par rapport au point
            textcoords='offset points',
            ha='right',            # Alignement horizontal
            va='bottom'            # Alignement vertical
        )

# Initialisation de l'algorithme t-SNE :
# - perplexity : influence la densité des groupes locaux
# - n_components=2 : réduction à 2 dimensions
# - init='pca' : initialisation via PCA (meilleure stabilité)
# - n_iter : nombre d’itérations pour l’optimisation
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)

# Nombre de mots à visualiser
plot_only = 500

# Réduction de dimension des 500 premiers vecteurs
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])

# Récupère les mots associés à ces vecteurs à partir de leur index
labels = [reverse_dictionary[i] for i in range(plot_only)]

# Appelle la fonction pour afficher le graphique
plot_with_labels(low_dim_embs, labels)
# Out:
# /Users/joachimjasmin/.pyenv/versions/3.12.10/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %% [markdown]
# # And voila!
#
# Now you have a visual understanding of embeddings.

# %% [markdown]
# Thank you for following this tutorial!
